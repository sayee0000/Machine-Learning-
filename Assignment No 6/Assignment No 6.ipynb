# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split 
from sklearn import metrics

# %%
col_names = ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age', 'label']
# load dataset
pima = pd.read_csv(r"C:\Users\91735\Downloads\diabetes.csv")

# %%
pima.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
from sklearn.metrics import accuracy_score
X = pima.drop("Outcome", axis=1)   # all columns except label
y = pima["Outcome"]
feature_cols = X.columns
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

clf = DecisionTreeClassifier()

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7012987012987013

# %%
import os
os.environ["PATH"] += os.pathsep + r"C:\Program Files\Graphviz\bin"

# %%
# !pip install pydotplus
# Out:
# Requirement already satisfied: pydotplus in c:\users\91735\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in c:\users\91735\anaconda3\lib\site-packages (from pydotplus) (3.0.9)

# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\users\91735\anaconda3\lib\site-packages (0.21)

# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\users\91735\anaconda3\lib\site-packages (0.21)

# %%
import os
os.environ["PATH"] += os.pathsep + r"C:\Program Files\Graphviz\bin"

# %%
from sklearn.tree import export_graphviz
from io import StringIO
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,
                feature_names=feature_cols,
                class_names=['0', '1'])

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('diabetes.png')
Image(graph.create_png())
