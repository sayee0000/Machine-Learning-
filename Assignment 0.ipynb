# %%
choice = int(input("Select the operation you want to perfrom:-\n1.Addition\n2.Subtraction\n3.Multiplication\n4.Division\n"));
a=int(input("Enter the value of A:- "));
b=int(input("Enter the value of b:- "));
match choice: 
 case 1:
        c=a+b;
        print(c);
 case 2:
        c=a-b;
        print(c);
 case 3:
        c=a*b;
        print(c);
 case 4:
        c=a/b;
        print(c);
 case _:
        print("Invalid Input");
# Out:
# Select the operation you want to perfrom:-
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# 1
# Enter the value of A:- 2
# Enter the value of b:- 2
# 4

# %%
import matplotlib.pyplot as plt
x = ["Apple","Banana","Mango","Orange"]
y = [30,45,10,20]
plt.bar(x, y, color='grey')
plt.xlabel("Fruits")
plt.ylabel("Quantity")
plt.title("Fruit Quantity Bar Graph")
plt.show()
