# %%
pip install scikit-learn-extra
# Out:
# Requirement already satisfied: scikit-learn-extra in c:\users\91735\anaconda3\lib\site-packages (0.3.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\91735\anaconda3\lib\site-packages (from scikit-learn-extra) (1.24.3)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\91735\anaconda3\lib\site-packages (from scikit-learn-extra) (1.11.1)
# Requirement already satisfied: scikit-learn>=0.23.0 in c:\users\91735\anaconda3\lib\site-packages (from scikit-learn-extra) (1.3.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\91735\anaconda3\lib\site-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\91735\anaconda3\lib\site-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn_extra.cluster import KMedoids
from sklearn.datasets import make_blobs

# %%
X, _ = make_blobs(n_samples=300, centers=3, cluster_std=1.05, random_state=42)
plt.scatter(X[:, 0], X[:, 1], s=50, c='gray', alpha=0.5)
plt.title("Raw Data Distribution")
plt.show()

# %%
k = 3
kmedoids = KMedoids(n_clusters=k, metric='euclidean', random_state=42)
kmedoids.fit(X)
labels = kmedoids.labels_
medoids = kmedoids.cluster_centers_
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', alpha=0.6)
plt.scatter(medoids[:, 0], medoids[:, 1], c='red', marker='X', s=200, label='Medoids')
plt.title("K-Medoids Clustering")
plt.legend()
plt.show()
